# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/forward_chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Initial fact
facts = {"Study"}

# Rule: If Study then Pass
if "Study" in facts:
    facts.add("Pass")

# Print inferred facts
print("Knowledge Base:")
for fact in facts:
    print(fact)
# Out:
# Knowledge Base:
# Pass
# Study
