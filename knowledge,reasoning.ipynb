# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/knowledge%2Creasoning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Knowledge Base
weather = "rainy"

# Reasoning
if weather == "rainy":
    print("Knowledge: It is rainy.")
    print("Reasoning: Carry an umbrella.")
else:
    print("Knowledge: Weather is clear.")
    print("Reasoning: No umbrella needed.")
# Out:
# Knowledge: It is rainy.
# Reasoning: Carry an umbrella.
