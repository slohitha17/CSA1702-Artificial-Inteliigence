# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/towers_of_honai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Towers of Hanoi

def hanoi(n, source, destination, auxiliary):

    if n == 1:
        print("Move disk from", source, "to", destination)
        return

    hanoi(n - 1, source, auxiliary, destination)

    print("Move disk from", source, "to", destination)

    hanoi(n - 1, auxiliary, destination, source)


# Input
n = 3
source = "A"
destination = "C"
auxiliary = "B"

hanoi(n, source, destination, auxiliary)
# Out:
# Move disk from A to C
# Move disk from A to B
# Move disk from C to B
# Move disk from A to C
# Move disk from B to A
# Move disk from B to C
# Move disk from A to C
