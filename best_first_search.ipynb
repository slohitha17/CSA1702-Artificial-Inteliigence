# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/best_first_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Best First Search

graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': ['G'],
    'G': []
}

# Heuristic values
h = {
    'A': 5,
    'B': 3,
    'C': 4,
    'D': 2,
    'E': 1,
    'F': 2,
    'G': 0
}

def best_first_search(start, goal):
    open_list = [start]
    visited = []

    while open_list:
        # Select node with lowest heuristic value
        current = min(open_list, key=lambda x: h[x])
        open_list.remove(current)

        print("Visiting:", current)
        visited.append(current)

        if current == goal:
            print("Goal reached!")
            return

        for neighbor in graph[current]:
            if neighbor not in visited and neighbor not in open_list:
                open_list.append(neighbor)

    print("Goal not found.")


# Query / Input
best_first_search('A', 'G')
# Out:
# Visiting: A
# Visiting: B
# Visiting: E
# Visiting: G
# Goal reached!
