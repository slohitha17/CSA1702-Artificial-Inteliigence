# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/smart_ac_ai_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("===== SMART AC AI AGENT =====")

temperature = int(input("Enter room temperature (°C): "))

print("\nAI Agent is observing the environment...")

if temperature >= 30:
    print("Decision: Turn ON the Air Conditioner")
else:
    print("Decision: Turn OFF the Air Conditioner")
# Out:
# ===== SMART AC AI AGENT =====
# Enter room temperature (°C): 35
#
# AI Agent is observing the environment...
# Decision: Turn ON the Air Conditioner
