# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/temp%2Chumid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperature = int(input())

humidity = int(input())

if temperature > 35 and humidity > 60:
    print("Fan Speed High")

elif temperature > 35:
    print("Fan Speed Medium")

else:
    print("OFF")
# Out:
# 17
# 24
# OFF
