# %% [markdown]
# <a href="https://colab.research.google.com/github/slohitha17/CSA1702-Artificial-Inteliigence/blob/main/heuristic_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Heuristic values (estimated distance to goal)

heuristic = {
    'A': 10,
    'B': 6,
    'C': 3,
    'Goal': 0
}

print("Heuristic Values:")
for node in heuristic:
    print(node, ":", heuristic[node])

best = min(heuristic, key=heuristic.get)

print("\nBest Node to Visit:", best)
# Out:
# Heuristic Values:
# A : 10
# B : 6
# C : 3
# Goal : 0
#
# Best Node to Visit: Goal
